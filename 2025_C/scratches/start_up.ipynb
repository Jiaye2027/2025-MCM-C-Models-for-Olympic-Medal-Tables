# %%
# pip install pandas scikit-learn matplotlib seaborn keras tensorflow xgboost lightgbm catboost
# Out:
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.0 MB 12.2 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 12.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 11.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 2.9/390.3 MB 14.0 MB/s eta 0:00:28
#     --------------------------------------- 5.8/390.3 MB 14.1 MB/s eta 0:00:28
# ...

# %%
import pandas as pd
# from sklearn import datasets
# import matplotlib.pyplot as plt
# import seaborn as sns
# import keras
# import tensorflow as tf
# import xgboost as xgb
# import lightgbm as lgb
# import catboost as cb

# %%
# data_dict_csv = pd.read_csv(r"2025_Problem_C_Data\data_dictionary.csv")
athletes_csv = pd.read_csv(r"2025_Problem_C_Data\summerOly_athletes.csv")
hosts_csv = pd.read_csv(r"2025_Problem_C_Data\summerOly_hosts.csv")
medal_counts_csv = pd.read_csv(r"2025_Problem_C_Data\summerOly_medal_counts.csv")
programs_csv = pd.read_csv(r"2025_Problem_C_Data\summerOly_programs.csv", encoding='windows-1252')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # data_dict_csv = pd.read_csv(r"2025_Problem_C_Data\data_dictionary.csv")
# ----> 2 athletes_csv = pd.read_csv(r"2025_Problem_C_Data\summerOly_athletes.csv")
#       3 hosts_csv = pd.read_csv(r"2025_Problem_C_Data\summerOly_hosts.csv")
#       4 medal_counts_csv = pd.read_csv(r"2025_Problem_C_Data\summerOly_medal_counts.csv")
#
# ...

# %%
athletes_csv.columns()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 athletes_csv.columns()
#
# NameError: name 'athletes_csv' is not defined
